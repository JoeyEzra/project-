# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw_data = 'C:/Users/User/Downloads/energydata_complete.csv'
df = pd.read_csv(raw_data)
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.duplicated().sum()
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.columns
df['date']=pd.to_datetime(df['date'], format='mixed', dayfirst=True)

# %%
df.head()
# Out:
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  datetime64[ns]
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.corr()
# Out:
#                  date  Appliances    lights        T1      RH_1        T2  \
# date         1.000000   -0.009630 -0.189835  0.696974 -0.102760  0.515321
# Appliances  -0.009630    1.000000  0.197278  0.055447  0.086031  0.120073
# lights      -0.189835    0.197278  1.000000 -0.023528  0.106968 -0.005622
# T1           0.696974    0.055447 -0.023528  1.000000  0.164006  0.836834
# RH_1        -0.102760    0.086031  0.106968  0.164006  1.000000  0.269839
# T2           0.515321    0.120073 -0.005622  0.836834  0.269839  1.000000
# RH_2        -0.092945   -0.060465  0.050985 -0.002509  0.797535 -0.165610
# T3           0.792938    0.085060 -0.097393  0.892402  0.253230  0.735245
# RH_3        -0.431939    0.036292  0.131161 -0.028550  0.844677  0.121497
# T4           0.781954    0.040281 -0.008859  0.877001  0.106180  0.762066
# RH_4        -0.263074    0.016965  0.114936  0.097861  0.880359  0.231563
# T5           0.777309    0.019760 -0.078745  0.885247  0.205797  0.720550
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df1 = df.drop(columns='date')
df2 = df1.corr(numeric_only=False)
plt.figure(figsize=(16, 12))
sns.heatmap(df2, fmt='.2f', annot=True, cmap='coolwarm')
plt.tight_layout()
plt.title('MultiCollinearity Test', size=(30))
# Out:
# Text(0.5, 1.0, 'MultiCollinearity Test')

# %%
#linearity
sns.scatterplot(data=df, x='T1', y='T2')
# Out:
# <Axes: xlabel='T1', ylabel='T2'>

# %%
cols = len(df.drop(columns=['date', 'Appliances']).columns)
count = 1
plt.figure(figsize=(cols, cols * 1.8))
plt.suptitle('Scatter plots of individual features against Appliances', y=0.9, size=30)

for i in df.drop(columns=['date', 'Appliances']).columns:
    plt.subplot(7, 4, count)
    plt.scatter(df[i], df['Appliances'])
    plt.xlabel(i)
    plt.ylabel('Appliances')
    count = count + 1
plt.show()

# %%
x = df.drop(columns=['Appliances', 'lights', 'date'])
y = df['Appliances']

# %%
x
# Out:
#               T1       RH_1         T2       RH_2         T3       RH_3  \
# 0      19.890000  47.596667  19.200000  44.790000  19.790000  44.730000
# 1      19.890000  46.693333  19.200000  44.722500  19.790000  44.790000
# 2      19.890000  46.300000  19.200000  44.626667  19.790000  44.933333
# 3      19.890000  46.066667  19.200000  44.590000  19.790000  45.000000
# 4      19.890000  46.333333  19.200000  44.530000  19.790000  45.000000
# ...          ...        ...        ...        ...        ...        ...
# 19730  25.566667  46.560000  25.890000  42.025714  27.200000  41.163333
# 19731  25.500000  46.500000  25.754000  42.080000  27.133333  41.223333
# 19732  25.500000  46.596667  25.628571  42.768571  27.050000  41.690000
# 19733  25.500000  46.990000  25.414000  43.036000  26.890000  41.290000
# 19734  25.500000  46.600000  25.264286  42.971429  26.823333  41.156667
#
#               T4       RH_4         T5       RH_5  ...         T9     RH_9  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Create an instance of the standard scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Trains the model on the training data
model.fit(x_train_scaled, y_train)

# uses the trained model to make Predictions 
model_pred = model.predict(x_train_scaled)

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
# root mean square error model performance evaluation
model_rmse = root_mean_squared_error(y_train, model_pred)

# mean absolute error model performance evaluation
model_mae = mean_absolute_error(y_train, model_pred)

# %%
print(f"The mean absolute error for the training set to three decimal places is: {model_mae:.3f}")
# Out:
# The mean absolute error for the training set to three decimal places is: 53.742

# %%
print(f"The root mean squared error for the training set to three decimal places is: {model_rmse:.3f}")
# Out:
# The root mean squared error for the training set to three decimal places is: 95.216

# %%
# Trains the model on the test data
#model.fit(x_test_scaled, y_test)

# uses the trained model of the test data to make Predictions 
test_pred = model.predict(x_test_scaled)

# %%
# root mean square error model performance evaluation
test_rmse = root_mean_squared_error(y_test, test_pred)

# mean absolute error model performance evaluation
test_mae = mean_absolute_error(y_test, test_pred)

# %%
print(f"The mean absolute error for the test set to three decimal places is: {test_mae:.3f}")
# Out:
# The mean absolute error for the test set to three decimal places is: 53.643

# %%
print(f"The root mean squared error for the test set to three decimal places is: {test_rmse:.3f}")
# Out:
# The root mean squared error for the test set to three decimal places is: 93.640

# %%
# r2 score to determine overfitting of data
r2_train = r2_score(y_train, model_pred)
r2_test= r2_score(y_test, test_pred)

# %%
print(f'The r2 score for the training set is: {r2_train:.3f}')
print(f'The r2 score for the test set is: {r2_test:.3f}')

# The model shows a very low performance
# Out:
# The r2 score for the training set is: 0.145
# The r2 score for the test set is: 0.149

# %%
from sklearn.linear_model import Ridge, Lasso
ridge = Ridge()

# Trains the model on the training data
ridge.fit(x_train, y_train)

# use the trained model to make Predictions
ridge_pred = ridge.predict(x_test)

# %%
ridge_rmse = root_mean_squared_error(y_test, ridge_pred)

# %%
print(f'The root mean square for ridge is: {ridge_rmse:.3f}')

# no difference was observed
# Out:
# The root mean square for ridge is: 93.641

# %%
lasso = Lasso()

# Trains the model on the training data
lasso.fit(x_train, y_train)

# use the trained model to make Predictions
lasso_pred = lasso.predict(x_test)

# %%
lasso_rmse = root_mean_squared_error(y_test, lasso_pred)

# %%
print(f'The root mean squared for lasso is: {lasso_rmse:.3f}')
# Out:
# The root mean squared for lasso is: 93.892

# %%
# Get the feature weights
lasso_weights = lasso.coef_

# Count how many are non-zero
non_zero_count = sum(i != 0 for i in lasso_weights)

print(f"Number of features with non-zero weights: {non_zero_count}")
# Out:
# Number of features with non-zero weights: 21

# %%
X = df[['T2']]
Y = df[['T6']]

# %%
from sklearn.linear_model import LinearRegression
# Create an instance of the model
lr = LinearRegression()

# Fit the data into the model
lr.fit(X, Y)

# Make predictions 
lr_pred = lr.predict(X)

# Obtain the root mean squared error
lr_rmse = root_mean_squared_error(Y, lr_pred)
print('The root mean square for the model is', round(lr_rmse, 3))
# Out:
# The root mean square for the model is 3.644
